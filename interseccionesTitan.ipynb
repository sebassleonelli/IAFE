# %%
from planetaryimage import PDS3Image
from matplotlib import pylab as plt
import numpy as np
import matplotlib.patches as patches
import requests
from bs4 import BeautifulSoup
import os
import zipfile
import io
import alphashape
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import shutil
from shapely.errors import TopologicalError
import math

# %%
# Parámetros y configuración inicial
volumenes = [35, 45, 65, 82, 86, 87, 93, 98, 100, 101, 108, 111, 120, 126, 127, 131, 149, 157, 161, 166, 167, 174, 177, 181, 189, 193, 195, 199, 200, 201, 203, 209, 210, 211, 218, 220, 229, 234, 239, 240, 243, 248, 250, 253, 261, 265, 271, 276, 277, 285]
output_dir = "pds_img"
os.makedirs(output_dir, exist_ok=True)
sampling=100
keywords = ["BIEQI", "BINQI", "BITQI"] #Falta cambiar de I a H
path= "C:/Users/ameli/Desktop/Cassini/pds_img"

# %%
#lista de angulos
def procesar_angulos(carpeta,sampling):
    img_dict = { "inc": None}

    for archivo in os.listdir(carpeta):
        if archivo.startswith("BIE"):
            img_dict["inc"] = PDS3Image.open(os.path.join(carpeta, archivo))

    inc = img_dict["inc"].image[::sampling, ::sampling].flatten()
    listInc=[]
    for i in range(inc.shape[0]):
        listInc.append(inc[i])
    
    return listInc

# %%
def generar_hull(carpeta, sampling=100, alpha=0.1):

    img_dict = {"lat": None, "lon": None, "inc": None}

    for archivo in os.listdir(carpeta):
        if archivo.startswith("BIN"):
            img_dict["lat"] = PDS3Image.open(os.path.join(carpeta, archivo))
        elif archivo.startswith("BIT"):
            img_dict["lon"] = PDS3Image.open(os.path.join(carpeta, archivo))
        elif archivo.startswith("BIE"):
            img_dict["inc"] = PDS3Image.open(os.path.join(carpeta, archivo))

    inc = img_dict["inc"].image[::sampling, ::sampling].flatten()
    lat = img_dict["lat"].image[::sampling, ::sampling].flatten()
    lon = img_dict["lon"].image[::sampling, ::sampling].flatten()

    lat = lat[inc > 0]
    lon = lon[inc > 0]

    latLonList = np.zeros((lon.shape[0], 2))
    for i in range(lat.shape[0]):
        latLonList[i] = np.array([lat[i], lon[i]])
    # Crear la lista de coordenadas (lat, lon)
    latLonList = np.zeros((lon.shape[0], 2))
    for i in range(lat.shape[0]):
        latLonList[i] = np.asarray([lat[i], lon[i]])

    # Generar el concave hull (alphashape)
    concave_hull = alphashape.alphashape(latLonList, alpha)

    if isinstance(concave_hull, Polygon):
        # Obtener los puntos del contorno exterior
        exterior_coords = list(concave_hull.exterior.coords)
    
    return exterior_coords

# %%
def descargar_y_extraer_zip(url, destino):
    try:
        print(f"Descargando {url} ...")
        respuesta = requests.get(url)
        
        if respuesta.status_code != 200:
            print(f"Error al descargar {url} (status: {respuesta.status_code}).")
            return

        # Leer el contenido del ZIP en memoria y extraerlo en `destino`
        with zipfile.ZipFile(io.BytesIO(respuesta.content)) as z:
            z.extractall(destino)
            print(f"Archivos extraídos en {destino}")

    except Exception as e:
        print(f"Error inesperado al procesar {url}: {e}")

# %%
def explorar_volumen(volumen_actual, output_dir, keywords):
    if volumen_actual < 100:
        base_url = f"https://planetarydata.jpl.nasa.gov/img/data/cassini/cassini_orbiter/CORADR_00{volumen_actual}/DATA/BIDR/"
    else:
        base_url = f"https://planetarydata.jpl.nasa.gov/img/data/cassini/cassini_orbiter/CORADR_0{volumen_actual}/DATA/BIDR/"

    volumen_dir = os.path.join(output_dir, f"volumen_{volumen_actual}")
    os.makedirs(volumen_dir, exist_ok=True)
    print(f"Carpeta creada para el volumen {volumen_actual}: {volumen_dir}")
    
    try:
        respuesta = requests.get(base_url)
        if respuesta.status_code != 200:
            print(f"No se pudo acceder al volumen {volumen_actual}. (status: {respuesta.status_code})")
            return volumen_dir

        soup = BeautifulSoup(respuesta.content, 'html.parser')
        enlaces = soup.find_all('a', href=True)

        for keyword in keywords:
            zip_encontrado = False
            for enlace in enlaces:
                href = enlace['href']
                if href.endswith('.ZIP') and keyword in href:
                    url_zip = base_url + href
                    descargar_y_extraer_zip(url_zip, volumen_dir)
                    zip_encontrado = True
                    print(f"Archivo '{href}' encontrado y descargado para la palabra clave '{keyword}'.")
                    break

            if not zip_encontrado:
                print(f"No se encontró el archivo ZIP con la palabra clave '{keyword}' en el volumen {volumen_actual}.")

        return volumen_dir

    except requests.exceptions.RequestException as e:
        print(f"Ocurrió un error al acceder a {base_url}: {e}")
        return volumen_dir
    except Exception as e:
        print(f"Ocurrió un error al explorar {base_url}: {e}")
        return volumen_dir

# %%
def procesar_volumenes(volumenes, output_dir, sampling=100):
    listIndices = []
    for volumen in volumenes:
        #carpeta_destino = explorar_volumen(volumen,output_dir,keywords) #comentar esta linea de codigo si ya tenes los archivos descargados
        carpeta_destino=os.path.join(output_dir, f"volumen_{volumen}")
        # Verificar si la carpeta contiene archivos después de la descarga
        if carpeta_destino and os.path.isdir(carpeta_destino):
            print(f"Archivos en {carpeta_destino}: {os.listdir(carpeta_destino)}")
            # Aquí podrías continuar con el procesamiento de las imágenes en la carpeta
            try:
                #listInc = promedio_angulos(procesar_angulos(carpeta_destino,sampling))
                latLonList = generar_hull(carpeta_destino, sampling=100)  # 'sampling' ajusta el nivel de detalle
                print(f"Puntos de latitud y longitud extraídos: {latLonList[:5]}...")  # Mostrar los primeros puntos
                if latLonList is not None and len(latLonList) > 0:  
                    listIndices.append((volumen,latLonList))
                    print(f"Contorno guardado para el volumen {volumen}")
                else:
                    print(f"No se pudo generar contorno para el volumen {volumen}")
            except Exception as e:
                print(f"Error al procesar las imágenes en {carpeta_destino}: {e}")
                latLonList = []
            else:
                print(f"No se encontraron puntos en el volumen {volumen}")
            
        else:
            print(f"No se pudo explorar o descargar archivos para el volumen {volumen}")

    # Mostrar el resultado final
    return listIndices

# %%
def interseccion(s, precision=5):
    intersecting_pairs = []
    for i in range(len(s)):
        j = i + 1
        # Redondear y validar el primer polígono
        poly1_coords = [(x,y) for x, y in s[i][1]]
        poly1 = Polygon(poly1_coords)
        if not poly1.is_valid:
            poly1 = poly1.buffer(0)  # Intentar corregir

        while j < len(s):
            # Redondear y validar el segundo polígono
            poly2_coords = [(x, y) for x, y in s[j][1]]
            poly2 = Polygon(poly2_coords)
            if not poly2.is_valid:
                poly2 = poly2.buffer(0)  # Intentar corregir
            
            try:
                if s[i][0] != s[j][0] and poly1.intersects(poly2):
                    # Aplicar buffer de 0 al momento de la intersección
                    area_interseccion = poly1.intersection(poly2)
                    if area_interseccion.geom_type == "MultiPolygon":
                        intersecting_pairs.append(((s[i][0], s[j][0]),"tiene dos áreas de intersección"))
                    else:
                        intersecting_pairs.append(((s[i][0], s[j][0]),area_interseccion))
            except TopologicalError as e:
                print(f"Error de topología entre los polígonos {s[i][0]} y {s[j][0]}: {e}")
            
            j += 1 
    return intersecting_pairs

listIndices=procesar_volumenes(volumenes,output_dir,sampling)
print(interseccion(listIndices,output_dir))
# Out:
# Archivos en pds_img\volumen_35: ['BIEQI49N071_D035_T00AS01_V03.IMG', 'BINQI49N071_D035_T00AS01_V03.IMG', 'BITQI49N071_D035_T00AS01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(46.283935546875, 51.99863052368164), (46.895751953125, 52.07122039794922), (47.50933837890625, 52.14112854003906), (48.12469482421875, 52.20833969116211), (48.741729736328125, 52.2728385925293)]...
# Contorno guardado para el volumen 35
# No se encontraron puntos en el volumen 35
# Archivos en pds_img\volumen_45: ['BIEQI22N068_D045_T003S01_V03.IMG', 'BINQI22N068_D045_T003S01_V03.IMG', 'BITQI22N068_D045_T003S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(89.21600341796875, 15.183061599731445), (86.58013916015625, 16.10784339904785), (86.1895751953125, 16.180526733398438), (85.79864501953125, 16.25196647644043), (85.40728759765625, 16.32215690612793)]...
# Contorno guardado para el volumen 45
# No se encontraron puntos en el volumen 45
# Archivos en pds_img\volumen_65: ['BIEQI10S251_D065_T008S01_V03.IMG', 'BINQI10S251_D065_T008S01_V03.IMG', 'BITQI10S251_D065_T008S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(233.98733520507812, -5.960414886474609), (234.377197265625, -5.95663595199585), (234.76707458496094, -5.952901840209961), (235.15695190429688, -5.949211597442627), (235.54681396484375, -5.945566177368164)]...
# Contorno guardado para el volumen 65
# No se encontraron puntos en el volumen 65
# Archivos en pds_img\volumen_82: ['BIEQI11S116_D082_T013S01_V03.IMG', 'BINQI11S116_D082_T013S01_V03.IMG', 'BITQI11S116_D082_T013S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(115.04109191894531, -7.866847038269043), (115.43165588378906, -7.86472225189209), (115.82223510742188, -7.862597942352295), (116.21281433105469, -7.860476016998291), (116.6033935546875, -7.858356952667236)]...
# Contorno guardado para el volumen 82
# No se encontraron puntos en el volumen 82
# Archivos en pds_img\volumen_86: []
# Error al procesar las imágenes en pds_img\volumen_86: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_87: ['BIEQI80N051_D087_T016S01_V03.IMG', 'BINQI80N051_D087_T016S01_V03.IMG', 'BITQI80N051_D087_T016S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_87: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_93: ['BIEQI10N052_D093_T017S01_V03.IMG', 'BINQI10N052_D093_T017S01_V03.IMG', 'BITQI10N052_D093_T017S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(45.46929931640625, 7.322870254516602), (45.09906005859375, 7.218748569488525), (44.72918701171875, 7.113796234130859), (44.359619140625, 7.00801944732666), (43.9903564453125, 6.901423931121826)]...
# Contorno guardado para el volumen 93
# No se encontraron puntos en el volumen 93
# Archivos en pds_img\volumen_98: ['BIEQI66N015_D098_T018S01_V03.IMG', 'BINQI66N015_D098_T018S01_V03.IMG', 'BITQI66N015_D098_T018S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_98: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_100: ['BIEQI69N342_D100_T019S01_V03.IMG', 'BINQI69N342_D100_T019S01_V03.IMG', 'BITQI69N342_D100_T019S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_100: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_101: []
# Error al procesar las imágenes en pds_img\volumen_101: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_108: ['BIEQI26N267_D108_T021S01_V03.IMG', 'BINQI26N267_D108_T021S01_V03.IMG', 'BITQI26N267_D108_T021S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(285.9947814941406, -13.028940200805664), (285.3265075683594, -10.809661865234375), (284.81884765625, -8.932119369506836), (284.30078125, -7.055060386657715), (283.59515380859375, -4.839526176452637)]...
# Contorno guardado para el volumen 108
# No se encontraron puntos en el volumen 108
# Archivos en pds_img\volumen_111: ['BIEQI26N009_D111_T023S01_V03.IMG', 'BINQI26N009_D111_T023S01_V03.IMG', 'BITQI26N009_D111_T023S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_111: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_120: ['BIEQI33N027_D120_T025S01_V03.IMG', 'BINQI33N027_D120_T025S01_V03.IMG', 'BITQI33N027_D120_T025S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_120: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_126: ['BIEQI52N010_D126_T028S01_V03.IMG', 'BINQI52N010_D126_T028S01_V03.IMG', 'BITQI52N010_D126_T028S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_126: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_127: ['BIEQI65N015_D127_T029S01_V03.IMG', 'BINQI65N015_D127_T029S01_V03.IMG', 'BITQI65N015_D127_T029S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_127: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_131: ['BIEQI61N250_D131_T030S01_V03.IMG', 'BINQI61N250_D131_T030S01_V03.IMG', 'BITQI61N250_D131_T030S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(310.7586975097656, 71.41073608398438), (311.93011474609375, 71.31143951416016), (313.0888671875, 71.2046127319336), (316.0838623046875, 70.47268676757812), (317.1675109863281, 70.33966827392578)]...
# Contorno guardado para el volumen 131
# No se encontraron puntos en el volumen 131
# Archivos en pds_img\volumen_149: ['BIEQI29S025_D149_T036S02_V03.IMG', 'BINQI29S025_D149_T036S02_V03.IMG', 'BITQI29S025_D149_T036S02_V03.IMG']
# Puntos de latitud y longitud extraídos: [(36.082305908203125, -49.14586639404297), (35.568511962890625, -49.34607696533203), (35.27349853515625, -49.0196647644043), (34.981475830078125, -48.69281768798828), (34.692474365234375, -48.36555862426758)]...
# Contorno guardado para el volumen 149
# No se encontraron puntos en el volumen 149
# Archivos en pds_img\volumen_157: ['BIEQI88S198_D157_T039S01_V03.IMG', 'BINQI88S198_D157_T039S01_V03.IMG', 'BITQI88S198_D157_T039S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_157: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_161: ['BIEQI10S194_D161_T041S02_V03.IMG', 'BINQI10S194_D161_T041S02_V03.IMG', 'BITQI10S194_D161_T041S02_V03.IMG']
# Puntos de latitud y longitud extraídos: [(211.52383422851562, 11.98904037475586), (211.8170928955078, 12.25394058227539), (212.1110076904297, 12.51845645904541), (212.40557861328125, 12.782578468322754), (212.6761016845703, 12.494629859924316)]...
# Contorno guardado para el volumen 161
# No se encontraron puntos en el volumen 161
# Archivos en pds_img\volumen_166: ['BIEQI09N141_D166_T043S01_V03.IMG', 'BINQI09N141_D166_T043S01_V03.IMG', 'BITQI09N141_D166_T043S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(191.44912719726562, 30.438488006591797), (191.8990936279297, 30.471553802490234), (192.34938049316406, 30.502857208251953), (192.7999725341797, 30.532394409179688), (193.25083923339844, 30.560157775878906)]...
# Contorno guardado para el volumen 166
# No se encontraron puntos en el volumen 166
# Archivos en pds_img\volumen_167: ['BIEQI03N158_D167_T044S01_V03.IMG', 'BINQI03N158_D167_T044S01_V03.IMG', 'BITQI03N158_D167_T044S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(150.52073669433594, -0.3727148473262787), (150.18141174316406, -0.5548418760299683), (149.84226989746094, -0.7373368740081787), (149.50331115722656, -0.9201931953430176), (149.16452026367188, -1.1034042835235596)]...
# Contorno guardado para el volumen 167
# No se encontraron puntos en el volumen 167
# Archivos en pds_img\volumen_174: ['BIEQI05N175_D174_T048S03_V03.IMG', 'BINQI05N175_D174_T048S03_V03.IMG', 'BITQI05N175_D174_T048S03_V03.IMG']
# Puntos de latitud y longitud extraídos: [(161.60107421875, -7.393885612487793), (161.92079162597656, -7.181607723236084), (164.3656768798828, -5.998144626617432), (164.68128967285156, -5.780188083648682), (164.996337890625, -5.561615467071533)]...
# Contorno guardado para el volumen 174
# No se encontraron puntos en el volumen 174
# Archivos en pds_img\volumen_177: ['BIEQI22S255_D177_T049S02_V03.IMG', 'BINQI22S255_D177_T049S02_V03.IMG', 'BITQI22S255_D177_T049S02_V03.IMG']
# Puntos de latitud y longitud extraídos: [(260.01824951171875, -15.791653633117676), (259.92529296875, -16.164459228515625), (259.83251953125, -16.53734016418457), (259.7398681640625, -16.910297393798828), (259.6473693847656, -17.283327102661133)]...
# Contorno guardado para el volumen 177
# No se encontraron puntos en el volumen 177
# Archivos en pds_img\volumen_181: ['BIEQI28S319_D181_T050S01_V03.IMG', 'BINQI28S319_D181_T050S01_V03.IMG', 'BITQI28S319_D181_T050S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_181: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_189: []
# Error al procesar las imágenes en pds_img\volumen_189: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_193: ['BIEQI26S167_D193_T055S01_V03.IMG', 'BINQI26S167_D193_T055S01_V03.IMG', 'BITQI26S167_D193_T055S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(252.55081176757812, -66.21122741699219), (253.5148162841797, -66.22271728515625), (254.47946166992188, -66.22845458984375), (255.4443359375, -66.22846221923828), (256.40899658203125, -66.22271728515625)]...
# Contorno guardado para el volumen 193
# No se encontraron puntos en el volumen 193
# Archivos en pds_img\volumen_195: ['BIEQI36S166_D195_T056S01_V03.IMG', 'BINQI36S166_D195_T056S01_V03.IMG', 'BITQI36S166_D195_T056S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(166.8586883544922, -40.33400344848633), (166.6494598388672, -39.98696517944336), (166.44171142578125, -39.6397705078125), (166.2353973388672, -39.29243850708008), (166.03050231933594, -38.944969177246094)]...
# Contorno guardado para el volumen 195
# No se encontraron puntos en el volumen 195
# Archivos en pds_img\volumen_199: ['BIEQI46S161_D199_T057S01_V03.IMG', 'BINQI46S161_D199_T057S01_V03.IMG', 'BITQI46S161_D199_T057S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_199: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_200: ['BIEQI62S167_D200_T058S01_V03.IMG', 'BINQI62S167_D200_T058S01_V03.IMG', 'BITQI62S167_D200_T058S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(193.5658416748047, -78.48109436035156), (192.272705078125, -78.20114135742188), (191.03741455078125, -77.91594696044922), (189.85693359375, -77.62589263916016), (188.72828674316406, -77.331298828125)]...
# Contorno guardado para el volumen 200
# No se encontraron puntos en el volumen 200
# Archivos en pds_img\volumen_201: ['BIEQI67S152_D201_T059S01_V03.IMG', 'BINQI67S152_D201_T059S01_V03.IMG', 'BITQI67S152_D201_T059S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(151.0852508544922, -44.6299934387207), (151.1944580078125, -45.007568359375), (151.30450439453125, -45.385128021240234), (151.41542053222656, -45.76266860961914), (151.52725219726562, -46.14018249511719)]...
# Contorno guardado para el volumen 201
# No se encontraron puntos en el volumen 201
# Archivos en pds_img\volumen_203: ['BIEQI08S236_D203_T061S01_V03.IMG', 'BINQI08S236_D203_T061S01_V03.IMG', 'BITQI08S236_D203_T061S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(255.0501251220703, -12.977129936218262), (254.65383911132812, -12.955902099609375), (251.9119873046875, -12.390718460083008), (251.51751708984375, -12.361859321594238), (251.1231689453125, -12.332046508789062)]...
# Contorno guardado para el volumen 203
# No se encontraron puntos en el volumen 203
# Archivos en pds_img\volumen_209: []
# Error al procesar las imágenes en pds_img\volumen_209: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_210: ['BIEQI69N225_D210_T064S01_V03.IMG', 'BINQI69N225_D210_T064S01_V03.IMG', 'BITQI69N225_D210_T064S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_210: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_211: ['BIEQI37S226_D211_T065S05_V03.IMG', 'BINQI37S226_D211_T065S05_V03.IMG', 'BITQI37S226_D211_T065S05_V03.IMG']
# Puntos de latitud y longitud extraídos: [(235.10382080078125, -22.055870056152344), (234.59751892089844, -23.28795051574707), (234.09530639648438, -24.528812408447266), (233.59652709960938, -25.77803611755371), (233.10035705566406, -27.03520393371582)]...
# Contorno guardado para el volumen 211
# No se encontraron puntos en el volumen 211
# Archivos en pds_img\volumen_218: []
# Error al procesar las imágenes en pds_img\volumen_218: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_220: ['BIEQI69S314_D220_T071S01_V03.IMG', 'BINQI69S314_D220_T071S01_V03.IMG', 'BITQI69S314_D220_T071S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_220: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_229: ['BIEQI08N038_D229_T077S04_V03.IMG', 'BINQI08N038_D229_T077S04_V03.IMG', 'BITQI08N038_D229_T077S04_V03.IMG']
# Puntos de latitud y longitud extraídos: [(35.994659423828125, 14.759685516357422), (35.99755859375, 14.369070053100586), (37.993408203125, 8.523286819458008), (38.38958740234375, 7.744729518890381), (40.36993408203125, 3.8518481254577637)]...
# Contorno guardado para el volumen 229
# No se encontraron puntos en el volumen 229
# Archivos en pds_img\volumen_234: []
# Error al procesar las imágenes en pds_img\volumen_234: 'NoneType' object has no attribute 'image'
# Archivos en pds_img\volumen_239: ['BIEQI75N177_D239_T083S01_V03.IMG', 'BINQI75N177_D239_T083S01_V03.IMG', 'BITQI75N177_D239_T083S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(195.14398193359375, 43.37184524536133), (194.332275390625, 46.450531005859375), (193.26515197753906, 49.892799377441406), (192.0765838623047, 53.326698303222656), (191.86614990234375, 53.693607330322266)]...
# Contorno guardado para el volumen 239
# No se encontraron puntos en el volumen 239
# Archivos en pds_img\volumen_240: ['BIEQI49N282_D240_T084S01_V03.IMG', 'BINQI49N282_D240_T084S01_V03.IMG', 'BITQI49N282_D240_T084S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_240: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_243: ['BIEQI61N226_D243_T086S01_V03.IMG', 'BINQI61N226_D243_T086S01_V03.IMG', 'BITQI61N226_D243_T086S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(223.8347625732422, 58.28756332397461), (223.6011199951172, 57.92584228515625), (223.37310791015625, 57.56352996826172), (223.15052795410156, 57.200645446777344), (222.93321228027344, 56.83721160888672)]...
# Contorno guardado para el volumen 243
# No se encontraron puntos en el volumen 243
# Archivos en pds_img\volumen_248: ['BIEQI26N247_D248_T091S01_V03.IMG', 'BINQI26N247_D248_T091S01_V03.IMG', 'BITQI26N247_D248_T091S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(254.77981567382812, 38.68115997314453), (254.69583129882812, 38.30427932739258), (254.61338806152344, 37.927249908447266), (254.5324249267578, 37.550071716308594), (254.4529266357422, 37.172752380371094)]...
# Contorno guardado para el volumen 248
# No se encontraron puntos en el volumen 248
# Archivos en pds_img\volumen_250: ['BIEQI39N235_D250_T092S01_V03.IMG', 'BINQI39N235_D250_T092S01_V03.IMG', 'BITQI39N235_D250_T092S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_250: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_253: ['BIEQI09N199_D253_T095S01_V03.IMG', 'BINQI09N199_D253_T095S01_V03.IMG', 'BITQI09N199_D253_T095S01_V03.IMG']
# Puntos de latitud y longitud extraídos: [(174.44622802734375, 51.86882400512695), (174.09661865234375, 52.18913269042969), (173.74139404296875, 52.50816345214844), (173.3804168701172, 52.82588195800781), (173.01358032226562, 53.142250061035156)]...
# Contorno guardado para el volumen 253
# No se encontraron puntos en el volumen 253
# Archivos en pds_img\volumen_261: ['BIEQI22N352_D261_T104S01_V03.IMG', 'BINQI22N352_D261_T104S01_V03.IMG', 'BITQI22N352_D261_T104S01_V03.IMG']
# Error al procesar las imágenes en pds_img\volumen_261: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_265: ['BIEQI36N017_D265_T108S01_V02.IMG', 'BINQI36N017_D265_T108S01_V02.IMG', 'BITQI36N017_D265_T108S01_V02.IMG']
# Puntos de latitud y longitud extraídos: [(20.792022705078125, 23.98925018310547), (20.812286376953125, 23.601789474487305), (20.832763671875, 23.21434211730957), (20.853485107421875, 22.826908111572266), (20.874420166015625, 22.43948745727539)]...
# Contorno guardado para el volumen 265
# No se encontraron puntos en el volumen 265
# Archivos en pds_img\volumen_271: ['BIEQI10S066_D271_T113S01_V02.IMG', 'BINQI10S066_D271_T113S01_V02.IMG', 'BITQI10S066_D271_T113S01_V02.IMG']
# Error al procesar las imágenes en pds_img\volumen_271: local variable 'exterior_coords' referenced before assignment
# Archivos en pds_img\volumen_276: ['BIEQI44S161_D276_T120S01_V02.IMG', 'BINQI44S161_D276_T120S01_V02.IMG', 'BITQI44S161_D276_T120S01_V02.IMG']
# Puntos de latitud y longitud extraídos: [(61.492431640625, -68.53458404541016), (58.199676513671875, -68.48778533935547), (57.247283935546875, -68.33975219726562), (56.3067626953125, -68.18689727783203), (55.378265380859375, -68.02932739257812)]...
# Contorno guardado para el volumen 276
# No se encontraron puntos en el volumen 276
# Archivos en pds_img\volumen_277: ['BIEQI07S128_D277_T121S01_V02.IMG', 'BINQI07S128_D277_T121S01_V02.IMG', 'BITQI07S128_D277_T121S01_V02.IMG']
# Puntos de latitud y longitud extraídos: [(133.2551727294922, -18.8966007232666), (132.95982360839844, -19.15761947631836), (132.66392517089844, -19.41855812072754), (132.3674774169922, -19.679407119750977), (132.07041931152344, -19.94016456604004)]...
# Contorno guardado para el volumen 277
# No se encontraron puntos en el volumen 277
# Archivos en pds_img\volumen_285: ['BIEQI53N079_D285_T126S05_V02.IMG', 'BINQI53N079_D285_T126S05_V02.IMG', 'BITQI53N079_D285_T126S05_V02.IMG']
# Puntos de latitud y longitud extraídos: [(97.25985717773438, 73.70874786376953), (95.41903686523438, 73.52325439453125), (93.61959838867188, 73.32257843017578), (91.86309814453125, 73.10730743408203), (90.15072631835938, 72.87805938720703)]...
# Contorno guardado para el volumen 285
# No se encontraron puntos en el volumen 285
# [((35, 193), <POLYGON ((127.982 36.597, 128.353 36.36, 128.722 36.122, 131.204 34.983, 13...>), ((35, 239), <POLYGON ((21.424 47.337, 20.358 45.031, 19.269 42.859, 18.57 42.181, 18.657...>), ((35, 265), <POLYGON ((20.61 38.608, 20.166 38.433, 15.618 34.376, 15.87 36.61, 16.094 3...>), ((35, 285), <POLYGON ((70.918 53.135, 71.552 53.097, 72.186 53.056, 72.818 53.011, 73.44...>), ((45, 166), <POLYGON ((125.117 -0.432, 123.566 -1.837, 122.881 -2.368, 122.373 -2.551, 1...>), ((45, 229), <POLYGON ((36.024 13.862, 35.644 13.767, 35.264 13.672, 35.221 13.661, 35.21...>), ((45, 265), <POLYGON ((21.889 7.428, 20.255 6.388, 19.342 5.609, 18.437 4.826, 16.999 3....>), ((65, 108), <POLYGON ((284.271 -6.264, 284.66 -6.267, 285.05 -6.27, 285.44 -6.272, 285.8...>), ((65, 161), <POLYGON ((190.496 -16.763, 189.334 -17.176, 187.782 -17.595, 185.84 -18.022...>), ((65, 177), <POLYGON ((257.377 -5.817, 257.767 -5.816, 258.157 -5.815, 258.546 -5.814, 2...>), ((65, 203), 'tiene dos áreas de intersección'), ((65, 211), <POLYGON ((241.93 -5.76, 241.797 -6.165, 241.509 -6.857, 241.225 -7.555, 240...>), ((65, 253), <POLYGON ((203.682 -13.013, 201.15 -13.42, 201.095 -13.139, 201.02 -12.76, 2...>), ((65, 276), <POLYGON ((183.273 -6.741, 182.928 -4.616, 183.061 -4.558, 184.274 -3.846, 1...>), ((82, 166), <POLYGON ((115.432 -7.865, 115.822 -7.863, 116.213 -7.86, 116.603 -7.858, 11...>), ((82, 167), <POLYGON ((132.611 -6.993, 133.002 -6.991, 133.392 -6.989, 133.783 -6.988, 1...>), ((82, 174), <POLYGON ((168.135 -4.509, 169.209 -5.933, 169.105 -6.008, 168.791 -6.234, 1...>), ((82, 193), <POLYGON ((155.644 -5.721, 156.035 -5.719, 156.425 -5.718, 156.816 -5.716, 1...>), ((82, 195), <POLYGON ((150.568 -5.74, 150.959 -5.739, 151.349 -5.737, 151.74 -5.735, 152...>), ((82, 200), <POLYGON ((142.37 -6.166, 142.76 -6.164, 143.151 -6.162, 143.541 -6.16, 143....>), ((82, 277), <POLYGON ((142.76 -6.164, 143.151 -6.162, 143.541 -6.16, 143.932 -6.159, 144...>), ((93, 229), <POLYGON ((39.34 5.072, 38.976 4.954, 38.85 4.914, 37.611 7.349, 37.235 8.08...>), ((108, 131), <POLYGON ((236.837 43.951, 236.371 44.134, 235.902 44.314, 235.43 44.493, 23...>), ((108, 177), <POLYGON ((273.53 14.131, 273.316 14.453, 273.101 14.774, 272.884 15.095, 27...>), ((108, 203), <POLYGON ((285.327 -10.81, 284.819 -8.932, 284.722 -8.581, 286.942 -7.939, 2...>), ((108, 239), <POLYGON ((201.371 47.771, 200.809 47.75, 200.248 47.725, 199.687 47.697, 19...>), ((108, 243), <POLYGON ((219.016 47.899, 218.463 47.983, 217.907 48.064, 217.349 48.142, 2...>), ((108, 248), <POLYGON ((253.901 34.744, 253.561 35.005, 253.218 35.265, 252.873 35.523, 2...>), ((131, 174), <POLYGON ((223.276 42.144, 223.45 42.511, 223.626 42.878, 223.646 42.919, 22...>), ((161, 203), <POLYGON ((208.149 -2.508, 206.228 -3.849, 205.048 -4.681, 204.713 -4.571, 2...>), ((161, 253), <POLYGON ((202.389 -6.563, 200.191 -8.205, 200.119 -8.278, 200.106 -8.213, 2...>), ((166, 167), 'tiene dos áreas de intersección'), ((166, 174), <POLYGON ((209.06 30.202, 207.736 28.995, 207.395 28.759, 207.056 28.522, 20...>), ((166, 193), <POLYGON ((151.863 10.611, 151.517 10.442, 151.172 10.271, 150.827 10.1, 150...>), ((166, 195), <POLYGON ((149.113 9.23, 148.772 9.054, 148.432 8.876, 148.092 8.698, 147.75...>), ((166, 200), <POLYGON ((142.076 5.355, 141.747 5.163, 141.419 4.969, 138.928 3.931, 138.6...>), ((166, 239), <POLYGON ((199.13 30.759, 199.583 30.762, 200.036 30.763, 200.489 30.762, 20...>), ((166, 243), <POLYGON ((213.043 29.629, 213.487 29.577, 216.209 29.616, 216.651 29.552, 2...>), ((166, 253), <POLYGON ((191.899 30.472, 192.349 30.503, 192.586 30.518, 192.652 30.347, 1...>), ((166, 277), 'tiene dos áreas de intersección'), ((167, 174), 'tiene dos áreas de intersección'), ((167, 193), <POLYGON ((150.231 3.457, 150.575 3.64, 150.919 3.821, 151.263 4.003, 151.60...>), ((167, 195), <POLYGON ((150.181 -0.555, 149.842 -0.737, 149.503 -0.92, 149.165 -1.103, 14...>), ((167, 200), <POLYGON ((147.473 -2.025, 147.135 -2.21, 144.964 -3.856, 144.627 -4 ...

# %%
def procesar_incidencia(carpeta, sampling=100):
    img_dict = {"lat": None, "lon": None, "inc": None}
    
    # Leer archivos en la carpeta
    for archivo in os.listdir(carpeta):
        if archivo.startswith("BIE"):  # Ajustar según el prefijo del archivo
            img_dict["inc"] = PDS3Image.open(os.path.join(carpeta, archivo))
    
    # Validar que se encontró el archivo de incidencia
    if img_dict["inc"] is None:
        raise FileNotFoundError("No se encontró el archivo de ángulos de incidencia en la carpeta.")
    
    # Extraer datos de incidencia
    inc = img_dict["inc"].image[::sampling, ::sampling].flatten()  # Reducir datos con sampling
    inc_validos = inc[inc > 0]  # Filtrar valores inválidos como ceros o negativos
    
    if len(inc_validos) == 0:
        raise ValueError("No hay valores válidos de incidencia en los datos.")
    
    # Calcular el promedio de ángulos de incidencia válidos
    promedio = np.mean(inc_validos)
    print(f"Promedio de ángulo de incidencia: {promedio:.2f} grados")
    return promedio

# Uso de la función

# %%
def limpiar_lista(intersecting_pairs, output_dir, sampling=100):
    nueva_lista = []
    for tupla,area in intersecting_pairs:
        area_interseccion=area
        carpeta_1 = f"{output_dir}/volumen_{tupla[0]}"
        carpeta_2 = f"{output_dir}/volumen_{tupla[1]}"
        inc_1 = procesar_incidencia(carpeta_1, sampling)
        inc_2 = procesar_incidencia(carpeta_2, sampling)
        resta = abs(inc_1 - inc_2)
        if resta >= 20:
            nueva_lista.append((tupla,inc_1,inc_2, resta,area_interseccion))
    
    # Guardar la lista final en un archivo de texto
    archivo_salida = os.path.join(output_dir, "lista_intersecciones.txt")
    with open(archivo_salida, "w") as f:
        for elemento in nueva_lista:
            f.write(f"{elemento}\n")
    
    print(f"Lista guardada en {archivo_salida}")
    return nueva_lista

# Uso de la función
lista_intersecciones = interseccion(listIndices, output_dir)
resultado_final = limpiar_lista(lista_intersecciones, output_dir)
# Out:
# Promedio de ángulo de incidencia: 24.40 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 24.40 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 24.40 grados
# Promedio de ángulo de incidencia: 21.66 grados
# Promedio de ángulo de incidencia: 24.40 grados
# Promedio de ángulo de incidencia: 35.31 grados
# Promedio de ángulo de incidencia: 19.09 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 19.09 grados
# Promedio de ángulo de incidencia: 14.80 grados
# Promedio de ángulo de incidencia: 19.09 grados
# Promedio de ángulo de incidencia: 21.66 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 13.64 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 22.17 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 21.00 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 20.49 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 35.98 grados
# Promedio de ángulo de incidencia: 14.80 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 22.99 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 22.17 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 40.85 grados
# Promedio de ángulo de incidencia: 26.51 grados
# Promedio de ángulo de incidencia: 26.76 grados
# Promedio de ángulo de incidencia: 22.99 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 13.64 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 13.64 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 40.85 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 21.57 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 40.85 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 18.95 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 40.85 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 42.10 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 22.17 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 21.65 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 21.67 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 21.72 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 41.26 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 21.31 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Promedio de ángulo de incidencia: 40.59 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 40.85 grados
# Promedio de ángulo de incidencia: 27.08 grados
# Promedio de ángulo de incidencia: 21.66 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 27.45 grados
# Promedio de ángulo de incidencia: 39.87 grados
# Promedio de ángulo de incidencia: 21.37 grados
# Lista guardada en pds_img\lista_intersecciones.txt
